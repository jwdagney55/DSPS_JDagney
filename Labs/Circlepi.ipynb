# %% [markdown]
# <a href="https://colab.research.google.com/github/jwdagney55/DSPS_JDagney/blob/main/Labs/Circlepi.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pylab as pl
#!pip install astropy
import astropy
from astropy import units as u


# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# What you know: The ratio of the area of the circle to the area of the square is π / 4.

# %%
def square(l, ax):
  ax.plot([-l, l], [-l, -l], 'k-')
  ax.plot([-l, l], [l, l], 'k-')
  ax.plot([-l, -l], [-l, l], 'k-')
  ax.plot([l, l], [-l, l], 'k-')

# %%
def circle(l, ax):
  theta = np.linspace(0, 360, 100)
  theta *= u.degree
  x = l * np.cos(theta.to(u.rad))
  y = l * np.sin(theta.to(u.rad))
  ax.plot(x, y, 'k-')

# %%
fig, ax = pl.subplots(figsize=(5, 5))
square(1, ax=ax)
circle(1, ax=ax)

# %%
def isin(x, y, l):
  #return ( ( ( l* np.cos(x)) ** 2 + ( (l * np.sin(y) )** 2) <= l ** 2 )
  return (  (l * x)**2 + (l * y )**2 <= l**2   )

# %%
np.random.seed(123)
xRands = np.random.rand(10000) * 2 - 1
yRands = np.random.rand(10000) * 2 - 1

# %%
val = np.array([], dtype=bool)
val = [ isin(xRands[i], yRands[i], 1) for i in range(len(xRands)) ]

# %%
val = isin(xRands, yRands, 1)

# %%
pi = val.sum()/len(val) * 4

# %%
pi
# Out:
# 3.1536

# %%
(pi - np.pi) / np.pi
# Out:
# 0.003822057069202288

# %%
ax = pl.figure(figsize=(7,7)).add_subplot()
square(1, ax=ax)
circle(1, ax=ax)
pl.plot(xRands, yRands, '.')
